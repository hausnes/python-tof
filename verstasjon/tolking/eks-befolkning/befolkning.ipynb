# %%
import pandas as pd

data = pd.read_csv("befolkning.csv", delimiter=";")
print(data.describe())
# Out:
#            Årstall    Befolkning  Levendefødte        Døde  Fødselsoverskudd  \
# count    71.000000     71.000000     71.000000   71.000000         71.000000
# mean   1986.000000  14826.929577    195.563380  156.788732         38.774648
# std      20.639767    417.074756     41.232696   18.916293         52.926687
# min    1951.000000  13792.000000    133.000000  121.000000        -45.000000
# 25%    1968.500000  14723.500000    163.500000  144.500000         -1.000000
# 50%    1986.000000  14858.000000    178.000000  154.000000         19.000000
# 75%    2003.500000  15098.500000    230.500000  169.000000         85.000000
# max    2021.000000  15787.000000    305.000000  198.000000        157.000000
#
#        Innflyttinger  Utflyttinger  Nettoinnflytting  Folketilvekst
# count      71.000000     71.000000         71.000000      71.000000
# mean      543.478873    552.253521         -8.774648      30.197183
# std       105.118282    114.840724         73.182199      66.704598
# ...

# %%
import csv
with open("befolkning.csv", encoding="utf-8-sig") as fil:
    filinnhold = csv.reader(fil, delimiter=";")

    overskrifter = next(filinnhold)
    print(overskrifter) #overskrifter[0],overskrifter[1]

    for rad in filinnhold:
        print(rad) # rad[0],rad[1]
# Out:
# ['Årstall', 'Befolkning', 'Levendefødte', 'Døde', 'Fødselsoverskudd', 'Innflyttinger', 'Utflyttinger', 'Nettoinnflytting', 'Folketilvekst']
# ['1951', '13845', '231', '123', '108', '445', '606', '-161', '-53']
# ['1952', '13792', '259', '125', '134', '410', '469', '-59', '75']
# ['1953', '13867', '269', '121', '148', '526', '515', '11', '159']
# ['1954', '14026', '254', '126', '128', '525', '645', '-120', '8']
# ['1955', '14034', '305', '148', '157', '502', '625', '-123', '66']
# ['1956', '14100', '260', '133', '127', '623', '663', '-40', '87']
# ['1957', '14187', '273', '126', '147', '643', '749', '-106', '41']
# ['1958', '14228', '264', '138', '126', '611', '666', '-55', '71']
# ['1959', '14299', '256', '127', '129', '578', '701', '-123', '6']
# ['1960', '14305', '261', '168', '93', '727', '851', '-124', '-11']
# ['1961', '14294', '266', '142', '124', '614', '644', '-30', '94']
# ['1962', '14388', '256', '154', '102', '656', '655', '1', '103']
# ...

# %%
import matplotlib.pyplot as plt

# Lister for å ta vare på alle årstall og befolkningsstørrelser
aarstall = []
befolkning = []

with open("befolkning.csv", encoding="utf-8-sig") as fil:
  filinnhold = csv.reader(fil, delimiter=";")

  overskrifter = next(filinnhold)
  print(overskrifter)
  
  for rad in filinnhold:
    aarstall.append(int(rad[0]))
    befolkning.append(int(rad[1]))

# Tegner grafen
plt.plot(aarstall, befolkning)
plt.grid()
plt.show()
# Out:
# ['Årstall', 'Befolkning', 'Levendefødte', 'Døde', 'Fødselsoverskudd', 'Innflyttinger', 'Utflyttinger', 'Nettoinnflytting', 'Folketilvekst']
